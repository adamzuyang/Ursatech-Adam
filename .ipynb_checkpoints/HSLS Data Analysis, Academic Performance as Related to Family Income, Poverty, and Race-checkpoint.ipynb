# %% [markdown]
# # High School Longitudinal Study Data Analysis: Academic Performance as Related to Family Income, Poverty, and Race
# - Ursaminor Jupyter Notebook
# - 12 November 2020
# - By Barnett Yang

# %% [markdown]
# ## Table of Contents
# * [Goals](#goals)
# * [Upload Raw Data](#data)
# * [Miscellaneous Notes and Libraries](#notes)
# * [Indicators and Relevant Variables](#variables)
# * [Academic Measures by Total Family Income: Mathematics, GPA, and College Attendance](#measuresByIncome)
# * [Academic Measures by Poverty: Mathematics, GPA, and College Attendance](#measuresByPoverty)
# * [Academic Measures by Race: Mathematics, GPA, and College Attendance](#measuresByRace)

# %% [markdown]
# ## Goals <a id='goals'></a>
# 1. Break up the HSLS dataframe into sub-dataframes tracking student sex, race, family income, and poverty levels.
# 2. Use each sub-dataframe to find academic performance averages, medians, max/min, and quintiles.
# 3. Form conclusions regarding student performance correlations to race and income.

# %% [markdown]
# ## Miscellaneous Notes and Libraries <a id='notes'></a>
# Data is compiled from the following online codebook that contains detailed descriptions of the dataset variables: https://nces.ed.gov/OnlineCodebook/Session/Codebook/3018b123-a88e-4e8c-aae2-b8c5917398d3
#
# For the above URL, select "Student File", "BY student level composites", and the relevant variables you'd like to analyze.
#
# The full variable list can be found here: https://nces.ed.gov/surveys/hsls09/hsls09_data.asp

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Indicators and Relevant Variables<a id='variables'></a>

# %% [markdown]
# ### Relevant Academic Success Indicators
# - X1TXMTH: Mathematics theta score.
#     - 2009 9th graders.
#     - Norm-referenced measure of achievement.
#     - Min: -8, Max: 3.0283, Mean: -0.6693, Std: 2.4536.
# - X1TXMSCR: Mathematics IRT-estimated number right score.
#     - 2009 9th graders.
#     - Min: -8, Max: 69.9317, Mean: 35.9645, Std: 17.7911.
# - X1TXMQUINT: Mathematics quintile score.
#     - 1 (lowest) to 5 (highest).
#     - Note: Remove unit non-response (-8).
#     - Based off of base year 2009 Mathematics Assessment of Algebraic Reasoning. See section 2.3 of https://nces.ed.gov/pubs2014/2014361.pdf for details.
# - X1TXMPROF1 - X1TXMPROF5: Mathematics proficiency probability scores.
#     - Min: -8, Max: 1.
# - S3CLGFT: Attending college full-time or part-time as of Nov 1 2013
#     - 1 = full-time; 2 = part-time; 3 = don't know.
#     - Note: Remove Unit non-response (-8) and Item legitimate skip/NA (-7).
# - S4EARNAMT2: Amount earned for February 2016/last job.
#     - May not be a good indicator since some students may still be in school.
# - S4HSGPA: Average grades in high school
#     - 1 mostly A's -> 7 D's and below.
#     - Note: Remove item legitimate skip (-7), unit non-response (-6), and item not administered (-4)

# %% [markdown]
# ### Sex, Race, Family Income, Poverty Level Variables
# - X1SEX: Student Sex.
# - X1RACE: Student Race.
#     - 1 = American Indian/Alaska Native
#     - 2 = Asian
#     - 3 = Black/African-American
#     - 4 = Hispanic, no race specified
#     - 5 = Hispanic, race specified
#     - 7 = Native Hawaiian/Pacific Islander
#     - 8 = White
# - X1FAMINCOME: Total family income from all sources (in US dollars, 2008).
#     - 1: <= 15000
#     - 2: > 15000 and <= 35000
#     - 3: > 35,000 and <= 55,000
#     - 4: > 55,000 and <= 75,000
#     - 5: > 75,000 and <= 95,000
#     - 6: > 95,000 and <= 115,000
#     - 7: > 115,000 and <= 135,000
#     - 8: > 135,000 and <= 155,000
#     - 9: > 155,000 and <= 175,000
#     - 10: > 175,000 and <= 195,000
#     - 11: > 195,000 and <= 215,000
#     - 12: > 215,000 and <= 235,000
#     - 13: > 235,000;
#     - -8: Unit non-response
# - X1POVERTY: X1 Poverty indicator.
#     - Relative to 100% of Census poverty threshold.
#     - 0: At or above poverty threshold
#     - 1: Below poverty threshold
#     - Note: Remove Unit non-response (-8).

# %% [markdown]
# ## Upload Raw Data <a class="anchor" id="data"></a>

# %%
hsls_student = pd.read_csv('../data/HSLS_2017_Datasets/hsls_17_student.csv')

# %%
# Collect above variables into a single dataframe
indicators = hsls_student[['STU_ID', 'X1SEX', 'X1RACE', 'X1FAMINCOME', 'X1POVERTY', 'X1TXMTH',
                           'X1TXMSCR', 'X1TXMQUINT','X1TXMPROF1', 'X1TXMPROF2', 'X1TXMPROF3', 
                           'X1TXMPROF4', 'X1TXMPROF5', 'S3CLGFT', 'S4HSGPA']]
indicators.head()
# Out:
#    STU_ID  X1SEX  X1RACE  X1FAMINCOME  X1POVERTY  X1TXMTH  X1TXMSCR  \
# 0   10001      1       8           10          0   0.8304   50.4919
# 1   10002      2       8            3          0  -0.2956   35.8045
# 2   10003      2       3            6          0   1.2997   56.0477
# 3   10004      2       8            5          0  -0.1427   38.0888
# 4   10005      1       8            9          0   1.1405   54.1762
#
#    X1TXMQUINT  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  X1TXMPROF5  \
# 0           5      0.9997      0.9669      0.8976      0.3126      0.1013
# 1           2      0.9714      0.5204      0.1768      0.0582      0.0512
# 2           5      1.0000      0.9914      0.9838      0.6606      0.2001
# 3           3      0.9843      0.6416      0.2459      0.0662      0.0531
# 4           5      0.9999      0.9863      0.9686      0.5385      0.1551
#
#    S3CLGFT  S4HSGPA
# 0        1       -7
# 1        1       -7
# 2        1       -7
# 3       -8       -7
# 4        3       -7

# %% [markdown]
# ## Academic Measures by Total Family Income: Math, GPA, and College Attendance <a id='measuresByIncome'></a>

# %% [markdown]
# ### Constants and Functions

# %%
# All relevant variables
academic_variables = ['X1TXMTH', 'X1TXMSCR', 'X1TXMQUINT', 'X1TXMPROF1', 'X1TXMPROF2', 'X1TXMPROF3',
                      'X1TXMPROF4', 'X1TXMPROF5', 'S4HSGPA', 'S3CLGFT']

# All continuous variables (can be analyzed similarly)
math_cont_variables = ['X1TXMTH', 'X1TXMSCR', 'X1TXMPROF1', 'X1TXMPROF2', 'X1TXMPROF3', 'X1TXMPROF4', 'X1TXMPROF5']

# Math quintiles variable
math_quintile = 'X1TXMQUINT'

# Entire high school GPA
gpa_variable = 'S4HSGPA'

# In college variable
college_variable = 'S3CLGFT'

# Takes in income_num from X1FAMINCOME column. Returns math performance table, 
# math quintile counts, GPA counts, and college status counts
def analyze_income(income_num):
    income = indicators[indicators['X1FAMINCOME'] == income_num]
    income_academic = income[academic_variables]
    
    income_cont = income_academic[math_cont_variables].describe()
    
    income_quint = income_academic[math_quintile].value_counts().to_frame()
    num_drop = len([i for i in income_quint.index if i < 0])
    income_quint = income_quint.sort_index().iloc[num_drop:]
    income_quint['PERCENT'] = income_quint[math_quintile] / income_quint[math_quintile].sum() * 100
    
    income_gpa = income_academic[gpa_variable].value_counts().to_frame()
    num_drop = len([i for i in income_gpa.index if i < 0])
    income_gpa = income_gpa.sort_index().iloc[num_drop:]
    income_gpa['PERCENT'] = income_gpa[gpa_variable] / income_gpa[gpa_variable].sum() * 100
    
    income_college = income_academic[college_variable].value_counts().to_frame()
    num_drop = len([i for i in income_college.index if i < 0])
    income_college = income_college.sort_index().iloc[num_drop:]
    income_college['PERCENT'] = income_college[college_variable] / income_college[college_variable].sum() * 100
    
    return income_cont, income_quint, income_gpa, income_college

# %% [markdown]
# ### Income less than or equal to 15,000 (in dollars)

# %%
income1_cont, income1_quint, income1_gpa, income1_college = analyze_income(1)
print(income1_cont, '\n\n', income1_quint, '\n\n', income1_gpa, '\n\n', income1_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  1570.000000  1570.000000  1570.000000  1570.000000  1570.000000
# mean     -0.582815    33.950478     0.555096     0.249965     0.069079
# std       1.540876    12.959122     1.484052     1.442758     1.403607
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -1.003775    25.761775     0.701800     0.107025     0.050900
# 50%      -0.346600    35.022550     0.965200     0.476900     0.158400
# 75%       0.140500    41.992300     0.995000     0.806650     0.433625
# max       3.028300    69.931700     1.000000     1.000000     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  1570.000000  1570.000000
# mean     -0.108786    -0.155890
# std       1.350471     1.334573
# min      -8.000000    -8.000000
# 25%       0.042100     0.047300
# 50%       0.056100     0.050700
# 75%       0.091300     0.058700
# max       0.998200     0.979600
#
#     X1TXMQUINT    PERCENT
# 1         418  27.391874
# 2         380  24.901704
# 3         327  21.428571
# 4         257  16.841415
# 5         144   9.436435
#
#     S4HSGPA    PERCENT
# 1       19   5.428571
# 2       51  14.571429
# 3       38  10.857143
# 4      120  34.285714
# 5       41  11.714286
# 6       42  12.000000
# 7       17   4.857143
# 8       22   6.285714
#
#     S3CLGFT    PERCENT
# 1      493  72.928994
# 2      101  14.940828
# 3       82  12.130178

# %% [markdown]
# ### Income greater than 15,000 and less than or equal to 35,000 (in dollars)

# %%
income2_cont, income2_quint, income2_gpa, income2_college = analyze_income(2)
print(income2_cont, '\n\n', income2_quint, '\n\n', income2_gpa, '\n\n', income2_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  3043.000000  3043.000000  3043.000000  3043.000000  3043.000000
# mean     -0.412168    35.603902     0.653753     0.354547     0.169411
# std       1.402877    12.664831     1.268822     1.243927     1.211854
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -0.869450    27.397900     0.792800     0.143900     0.060650
# 50%      -0.248300    36.521800     0.976200     0.559800     0.195800
# 75%       0.266400    43.605300     0.997000     0.856200     0.535000
# max       2.909700    69.577300     1.000000     0.999900     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  3043.000000  3043.000000
# mean     -0.025466    -0.085797
# std       1.156141     1.135239
# min      -8.000000    -8.000000
# 25%       0.043700     0.047700
# 50%       0.060400     0.051800
# 75%       0.109500     0.062500
# max       0.997400     0.968100
#
#     X1TXMQUINT    PERCENT
# 1         700  23.474178
# 2         728  24.413146
# 3         654  21.931590
# 4         521  17.471496
# 5         379  12.709591
#
#     S4HSGPA    PERCENT
# 1       26   4.593640
# 2      120  21.201413
# 3       47   8.303887
# 4      172  30.388693
# 5       72  12.720848
# 6       67  11.837456
# 7       28   4.946996
# 8       34   6.007067
#
#     S3CLGFT    PERCENT
# 1     1134  76.829268
# 2      193  13.075881
# 3      149  10.094851

# %% [markdown]
# ### Income greater than 35,000 and less than or equal to 55,000 (in dollars)

# %%
income3_cont, income3_quint, income3_gpa, income3_college = analyze_income(3)
print(income3_cont, '\n\n', income3_quint, '\n\n', income3_gpa, '\n\n', income3_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  2762.000000  2762.000000  2762.000000  2762.000000  2762.000000
# mean     -0.170179    38.578867     0.715124     0.460508     0.277381
# std       1.398496    13.023404     1.198455     1.187474     1.165933
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -0.609375    31.000525     0.909450     0.269375     0.093225
# 50%      -0.039500    39.562950     0.989600     0.711100     0.305700
# 75%       0.609925    47.837375     0.999300     0.939675     0.791850
# max       2.772300    69.076600     1.000000     0.999900     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  2762.000000  2762.000000
# mean      0.038713    -0.053177
# std       1.104095     1.072878
# min      -8.000000    -8.000000
# 25%       0.048225     0.048800
# 50%       0.073500     0.054800
# 75%       0.201675     0.080275
# max       0.995900     0.947700
#
#     X1TXMQUINT    PERCENT
# 1         479  17.655732
# 2         528  19.461850
# 3         575  21.194250
# 4         599  22.078879
# 5         532  19.609289
#
#     S4HSGPA    PERCENT
# 1       36   9.863014
# 2       79  21.643836
# 3       45  12.328767
# 4      106  29.041096
# 5       38  10.410959
# 6       37  10.136986
# 7       12   3.287671
# 8       12   3.287671
#
#     S3CLGFT    PERCENT
# 1     1356  85.336690
# 2      128   8.055381
# 3      105   6.607930

# %% [markdown]
# ### Income greater than 55,000 and less than or equal to 75,000 (in dollars)

# %%
income4_cont, income4_quint, income4_gpa, income4_college = analyze_income(4)
print(income4_cont, '\n\n', income4_quint, '\n\n', income4_gpa, '\n\n', income4_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  2514.000000  2514.000000  2514.000000  2514.000000  2514.000000
# mean     -0.004480    40.799786     0.725573     0.500525     0.317751
# std       1.472373    13.180656     1.297082     1.287876     1.270366
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -0.406725    34.095625     0.956375     0.425500     0.139525
# 50%       0.130650    41.863200     0.994800     0.802200     0.425950
# 75%       0.774600    49.823100     0.999600     0.961350     0.875975
# max       3.028300    69.931700     1.000000     1.000000     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  2514.000000  2514.000000
# mean      0.046891    -0.066329
# std       1.207172     1.170922
# min      -8.000000    -8.000000
# 25%       0.053925     0.050200
# 50%       0.090100     0.058450
# 75%       0.279925     0.094950
# max       0.998200     0.979600
#
#     X1TXMQUINT    PERCENT
# 1         293  11.905729
# 2         408  16.578627
# 3         509  20.682649
# 4         626  25.436814
# 5         625  25.396180
#
#     S4HSGPA    PERCENT
# 1       42  14.946619
# 2       76  27.046263
# 3       38  13.523132
# 4       63  22.419929
# 5       21   7.473310
# 6       24   8.540925
# 7        8   2.846975
# 8        9   3.202847
#
#     S3CLGFT    PERCENT
# 1     1433  87.112462
# 2      132   8.024316
# 3       80   4.863222

# %% [markdown]
# ### Income greater than 75,000 and less than or equal to 95,000 (in dollars)

# %%
income5_cont, income5_quint, income5_gpa, income5_college = analyze_income(5)
print(income5_cont, '\n\n', income5_quint, '\n\n', income5_gpa, '\n\n', income5_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  1855.000000  1855.000000  1855.000000  1855.000000  1855.000000
# mean      0.103761    42.195180     0.730594     0.525814     0.351980
# std       1.513794    13.489307     1.325910     1.318901     1.305138
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -0.319050    35.444750     0.968700     0.500450     0.168050
# 50%       0.217000    42.979200     0.996300     0.838200     0.494600
# 75%       0.933200    51.719250     0.999800     0.975200     0.929450
# max       3.028300    69.931700     1.000000     1.000000     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  1855.000000  1855.000000
# mean      0.074139    -0.060536
# std       1.244595     1.201785
# min      -8.000000    -8.000000
# 25%       0.057200     0.051000
# 50%       0.101700     0.060900
# 75%       0.380550     0.115250
# max       0.998200     0.979600
#
#     X1TXMQUINT    PERCENT
# 1         192  10.584344
# 2         254  14.002205
# 3         356  19.625138
# 4         440  24.255788
# 5         572  31.532525
#
#     S4HSGPA    PERCENT
# 1       37  18.592965
# 2       62  31.155779
# 3       21  10.552764
# 4       41  20.603015
# 5       15   7.537688
# 6       15   7.537688
# 7        2   1.005025
# 8        6   3.015075
#
#     S3CLGFT    PERCENT
# 1     1248  91.094891
# 2       74   5.401460
# 3       48   3.503650

# %% [markdown]
# ### Income greater than 95,000 and less than or equal to 115,000 (in dollars)

# %%
income6_cont, income6_quint, income6_gpa, income6_college = analyze_income(6)
print(income6_cont, '\n\n', income6_quint, '\n\n', income6_gpa, '\n\n', income6_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  1484.000000  1484.000000  1484.000000  1484.000000  1484.000000
# mean      0.246808    43.886435     0.765534     0.585231     0.416353
# std       1.478721    13.177925     1.270075     1.266127     1.258276
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -0.185075    37.466300     0.981425     0.609925     0.224475
# 50%       0.377200    44.989200     0.998100     0.890300     0.625350
# 75%       1.012025    52.656550     0.999900     0.980150     0.947700
# max       3.028300    69.931700     1.000000     1.000000     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  1484.000000  1484.000000
# mean      0.119042    -0.031221
# std       1.201278     1.155750
# min      -8.000000    -8.000000
# 25%       0.063750     0.052575
# 50%       0.131100     0.066850
# 75%       0.438375     0.128375
# max       0.998200     0.979600
#
#     X1TXMQUINT    PERCENT
# 1          98   6.740028
# 2         194  13.342503
# 3         269  18.500688
# 4         381  26.203576
# 5         512  35.213205
#
#     S4HSGPA    PERCENT
# 1       25  17.241379
# 2       42  28.965517
# 3       17  11.724138
# 4       34  23.448276
# 5       13   8.965517
# 6        8   5.517241
# 7        4   2.758621
# 8        2   1.379310
#
#     S3CLGFT    PERCENT
# 1     1066  93.345009
# 2       53   4.640981
# 3       23   2.014011

# %% [markdown]
# ### Income greater than 115,000 and less than or equal to 135,000 (in dollars)

# %%
income7_cont, income7_quint, income7_gpa, income7_college = analyze_income(7)
print(income7_cont, '\n\n', income7_quint, '\n\n', income7_gpa, '\n\n', income7_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  964.000000  964.000000  964.000000  964.000000  964.000000  964.000000
# mean     0.274545   44.151812    0.780150    0.604748    0.435188    0.135292
# std      1.441700   13.003665    1.222627    1.220520    1.214156    1.159405
# min     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 25%     -0.152650   37.943175    0.983600    0.634275    0.240700    0.065600
# 50%      0.390800   45.157400    0.998250    0.893950    0.636150    0.134200
# 75%      1.039875   52.986775    0.999900    0.981725    0.953075    0.459675
# max      3.028300   69.931700    1.000000    1.000000    1.000000    0.998200
#
#        X1TXMPROF5
# count  964.000000
# mean    -0.017003
# std      1.113220
# min     -8.000000
# 25%      0.053000
# 50%      0.067450
# 75%      0.133575
# max      0.979600
#
#     X1TXMQUINT    PERCENT
# 1          64   6.765328
# 2         111  11.733615
# 3         175  18.498943
# 4         264  27.906977
# 5         332  35.095137
#
#     S4HSGPA    PERCENT
# 1       12  12.244898
# 2       31  31.632653
# 3       16  16.326531
# 4       16  16.326531
# 5        8   8.163265
# 6        7   7.142857
# 7        6   6.122449
# 8        2   2.040816
#
#     S3CLGFT    PERCENT
# 1      745  93.241552
# 2       32   4.005006
# 3       22   2.753442

# %% [markdown]
# ### Income greater than 135,000 and less than or equal to 155,000 (in dollars)

# %%
income8_cont, income8_quint, income8_gpa, income8_college = analyze_income(8)
print(income8_cont, '\n\n', income8_quint, '\n\n', income8_gpa, '\n\n', income8_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  741.000000  741.000000  741.000000  741.000000  741.000000  741.000000
# mean     0.459394   46.058148    0.843262    0.690849    0.541690    0.234567
# std      1.316508   12.694180    0.993861    1.003231    1.008077    0.964635
# min     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 25%     -0.036700   39.601800    0.989700    0.712900    0.307400    0.073700
# 50%      0.575100   47.415000    0.999200    0.933900    0.770200    0.188500
# 75%      1.178700   54.626900    0.999900    0.987800    0.973100    0.568600
# max      3.028300   69.931700    1.000000    1.000000    1.000000    0.998200
#
#        X1TXMPROF5
# count  741.000000
# mean     0.060706
# std      0.914435
# min     -8.000000
# 25%      0.054800
# 50%      0.077800
# 75%      0.164600
# max      0.979600
#
#     X1TXMQUINT    PERCENT
# 1          46   6.284153
# 2          71   9.699454
# 3         111  15.163934
# 4         200  27.322404
# 5         304  41.530055
#
#     S4HSGPA    PERCENT
# 1       16  30.188679
# 2       18  33.962264
# 3        9  16.981132
# 4        8  15.094340
# 6        2   3.773585
#
#     S3CLGFT    PERCENT
# 1      588  95.299838
# 2       23   3.727715
# 3        6   0.972447

# %% [markdown]
# ### Income greater than 155,000 and less than or equal to 175,000 (in dollars)

# %%
income9_cont, income9_quint, income9_gpa, income9_college = analyze_income(9)
print(income9_cont, '\n\n', income9_quint, '\n\n', income9_gpa, '\n\n', income9_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  367.000000  367.000000  367.000000  367.000000  367.000000  367.000000
# mean     0.399526   45.565394    0.804542    0.651710    0.500969    0.190713
# std      1.406570   12.975761    1.147707    1.150427    1.150010    1.099598
# min     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 25%     -0.075000   39.062600    0.987950    0.688450    0.283900    0.070800
# 50%      0.575900   47.423800    0.999200    0.934000    0.770600    0.188700
# 75%      1.133250   54.090900    0.999900    0.986000    0.967650    0.532800
# max      3.028300   69.931700    1.000000    1.000000    1.000000    0.998200
#
#        X1TXMPROF5
# count  367.000000
# mean     0.017783
# std      1.049515
# min     -8.000000
# 25%      0.054200
# 50%      0.077800
# 75%      0.153400
# max      0.979600
#
#     X1TXMQUINT    PERCENT
# 1          26   7.202216
# 2          32   8.864266
# 3          61  16.897507
# 4          94  26.038781
# 5         148  40.997230
#
#     S4HSGPA  PERCENT
# 1        5   15.625
# 2       13   40.625
# 3        3    9.375
# 4        5   15.625
# 6        5   15.625
# 7        1    3.125
#
#     S3CLGFT    PERCENT
# 1      298  94.303797
# 2       11   3.481013
# 3        7   2.215190

# %% [markdown]
# ### Income greater than 175,000 and less than or equal to 195,000 (in dollars)

# %%
income10_cont, income10_quint, income10_gpa, income10_college = analyze_income(10)
print(income10_cont, '\n\n', income10_quint, '\n\n', income10_gpa, '\n\n', income10_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  237.000000  237.000000  237.000000  237.000000  237.000000  237.000000
# mean     0.450008   46.422916    0.774471    0.631961    0.469544    0.179993
# std      1.541172   13.573174    1.298571    1.292853    1.289701    1.248137
# min     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 25%     -0.053900   39.361300    0.989000    0.702100    0.296700    0.072300
# 50%      0.520300   46.747300    0.999000    0.923700    0.733400    0.169700
# 75%      1.273500   55.740400    1.000000    0.990700    0.981900    0.641300
# max      2.709100   68.809200    1.000000    0.999900    1.000000    0.994900
#
#        X1TXMPROF5
# count  237.000000
# mean     0.006918
# std      1.196193
# min     -8.000000
# 25%      0.054500
# 50%      0.074300
# 75%      0.191600
# max      0.934900
#
#     X1TXMQUINT    PERCENT
# 1          10   4.310345
# 2          19   8.189655
# 3          44  18.965517
# 4          60  25.862069
# 5          99  42.672414
#
#     S4HSGPA    PERCENT
# 1        4  26.666667
# 2        3  20.000000
# 3        3  20.000000
# 4        2  13.333333
# 5        2  13.333333
# 8        1   6.666667
#
#     S3CLGFT  PERCENT
# 1      191     95.5
# 2        7      3.5
# 3        2      1.0

# %% [markdown]
# ### Income greater than 195,000 and less than or equal to 215,000 (in dollars)

# %%
income11_cont, income11_quint, income11_gpa, income11_college = analyze_income(11)
print(income11_cont, '\n\n', income11_quint, '\n\n', income11_gpa, '\n\n', income11_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  316.000000  316.000000  316.000000  316.000000  316.000000  316.000000
# mean     0.484141   46.649060    0.800607    0.649696    0.495674    0.203076
# std      1.473642   13.149763    1.230213    1.230894    1.230859    1.188138
# min     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 25%     -0.033300   39.649875    0.989850    0.714950    0.309600    0.073925
# 50%      0.615100   47.899750    0.999300    0.940450    0.794800    0.203900
# 75%      1.307975   56.144425    1.000000    0.991625    0.984375    0.666550
# max      3.028300   69.931700    1.000000    1.000000    1.000000    0.998200
#
#        X1TXMPROF5
# count  316.000000
# mean     0.018335
# std      1.134798
# min     -8.000000
# 25%      0.054875
# 50%      0.080700
# 75%      0.202800
# max      0.979600
#
#     X1TXMQUINT    PERCENT
# 1          14   4.516129
# 2          27   8.709677
# 3          55  17.741935
# 4          76  24.516129
# 5         138  44.516129
#
#     S4HSGPA  PERCENT
# 1        5     20.0
# 2       11     44.0
# 3        2      8.0
# 4        6     24.0
# 6        1      4.0
#
#     S3CLGFT    PERCENT
# 1      260  94.890511
# 2       11   4.014599
# 3        3   1.094891

# %% [markdown]
# ### Income greater than 215,000 and less than or equal to 235,000 (in dollars)

# %%
income12_cont, income12_quint, income12_gpa, income12_college = analyze_income(12)
print(income12_cont, '\n\n', income12_quint, '\n\n', income12_gpa, '\n\n', income12_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  116.000000  116.000000  116.000000  116.000000  116.000000  116.000000
# mean     0.625949   47.989616    0.894788    0.769096    0.636376    0.301398
# std      1.150413   11.335990    0.840468    0.855996    0.870851    0.833246
# min     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 25%      0.163275   42.286775    0.995400    0.816350    0.451575    0.094275
# 50%      0.791100   50.021300    0.999650    0.963000    0.882650    0.289350
# 75%      1.243200   55.384925    0.999925    0.989875    0.979400    0.618475
# max      2.794500   69.164700    1.000000    0.999900    1.000000    0.996200
#
#        X1TXMPROF5
# count  116.000000
# mean     0.092914
# std      0.778379
# min     -8.000000
# 25%      0.059375
# 50%      0.096800
# 75%      0.182425
# max      0.951600
#
#     X1TXMQUINT    PERCENT
# 1           5   4.347826
# 2           8   6.956522
# 3          15  13.043478
# 4          29  25.217391
# 5          58  50.434783
#
#     S4HSGPA    PERCENT
# 1        3  20.000000
# 2        7  46.666667
# 3        4  26.666667
# 6        1   6.666667
#
#     S3CLGFT  PERCENT
# 1       98     98.0
# 2        1      1.0
# 3        1      1.0

# %% [markdown]
# ### Income greater than 235,000 (in dollars)

# %%
income13_cont, income13_quint, income13_gpa, income13_college = analyze_income(13)
print(income13_cont, '\n\n', income13_quint, '\n\n', income13_gpa, '\n\n', income13_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  792.000000  792.000000  792.000000  792.000000  792.000000  792.000000
# mean     0.642107   48.291184    0.867411    0.743123    0.612039    0.304473
# std      1.273688   12.221387    0.959007    0.968855    0.980227    0.947899
# min     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 25%      0.080125   41.195925    0.993600    0.778075    0.387750    0.084400
# 50%      0.806350   50.203850    0.999700    0.964600    0.888700    0.298150
# 75%      1.331500   56.418900    1.000000    0.992200    0.985825    0.683250
# max      3.028300   69.931700    1.000000    1.000000    1.000000    0.998200
#
#        X1TXMPROF5
# count  792.000000
# mean     0.091835
# std      0.889883
# min     -8.000000
# 25%      0.057200
# 50%      0.098450
# 75%      0.210875
# max      0.979600
#
#     X1TXMQUINT    PERCENT
# 1          33   4.214559
# 2          53   6.768838
# 3         114  14.559387
# 4         179  22.860792
# 5         404  51.596424
#
#     S4HSGPA    PERCENT
# 1       29  33.333333
# 2       34  39.080460
# 3       13  14.942529
# 4        5   5.747126
# 5        4   4.597701
# 6        1   1.149425
# 8        1   1.149425
#
#     S3CLGFT    PERCENT
# 1      663  96.506550
# 2       13   1.892285
# 3       11   1.601164

# %% [markdown]
# ### Aggregate Tables

# %%
income_gpas_array = [income1_gpa, income2_gpa, income3_gpa, income4_gpa, income5_gpa, income6_gpa, income7_gpa, 
              income8_gpa, income9_gpa, income10_gpa, income11_gpa, income12_gpa, income13_gpa]

income_gpas = pd.DataFrame()
for i in range(len(income_gpas_array)):
    income_gpas['INCOME BRACKET ' + str(i + 1)] = income_gpas_array[i]['S4HSGPA']
    income_gpas['INCOME BRACKET ' + str(i + 1) + ' PERCENT'] = income_gpas_array[i]['PERCENT'] 
income_gpas.fillna(0, inplace=True)

plt.figure(0, figsize=(10, 8), dpi=80)
plt.plot(income_gpas['INCOME BRACKET 1 PERCENT'], label='INCOME 1: <= 15000')
#plt.plot(income_gpas['INCOME BRACKET 2 PERCENT'], label='INCOME 2: > 15000 and <= 35000')
#plt.plot(income_gpas['INCOME BRACKET 3 PERCENT'], label='INCOME 3: > 35000 and <= 55000')
plt.plot(income_gpas['INCOME BRACKET 4 PERCENT'], label='INCOME 4: > 55000 and <= 75000')
#plt.plot(income_gpas['INCOME BRACKET 5 PERCENT'], label='INCOME 5: > 75000 and <= 95000')
#plt.plot(income_gpas['INCOME BRACKET 6 PERCENT'], label='INCOME 6: > 95000 and <= 115000')
plt.plot(income_gpas['INCOME BRACKET 7 PERCENT'], label='INCOME 7: > 115000 and <= 135000')
#plt.plot(income_gpas['INCOME BRACKET 8 PERCENT'], label='INCOME 8: > 135000 and <= 155000')
#plt.plot(income_gpas['INCOME BRACKET 9 PERCENT'], label='INCOME 9: > 155000 and <= 175000')
plt.plot(income_gpas['INCOME BRACKET 10 PERCENT'], label='INCOME 10: > 175000 and <= 195000')
#plt.plot(income_gpas['INCOME BRACKET 11 PERCENT'], label='INCOME 11: > 195000 and <= 215000')
#plt.plot(income_gpas['INCOME BRACKET 12 PERCENT'], label='INCOME 12: > 215000 and <= 235000')
plt.plot(income_gpas['INCOME BRACKET 13 PERCENT'], label='INCOME 13: > 235000')
plt.legend()
plt.title('Relative Grades Earned as Income Increases')
plt.ylabel('Percent of Students')
plt.xlabel('Grade')


income_colleges_array = [income1_college, income2_college, income3_college, income4_college, income5_college, 
                       income6_college, income7_college, income8_college, income9_college, income10_college, 
                       income11_college, income12_college, income13_college]

income_colleges = pd.DataFrame()
for i in range(len(income_colleges_array)):
    income_colleges['INCOME BRACKET ' + str(i + 1)] = income_colleges_array[i]['S3CLGFT']
    income_colleges['INCOME BRACKET ' + str(i + 1) + ' PERCENT'] = income_gpas_array[i]['PERCENT']
income_colleges.fillna(0, inplace=True)

plt.figure(1, figsize=(10, 8), dpi=80)
plt.plot(income_colleges['INCOME BRACKET 1 PERCENT'], label='INCOME 1: <= 15000')
#plt.plot(income_colleges['INCOME BRACKET 2 PERCENT'], label='INCOME 2: > 15000 and <= 35000')
#plt.plot(income_colleges['INCOME BRACKET 3 PERCENT'], label='INCOME 3: > 35000 and <= 55000')
plt.plot(income_colleges['INCOME BRACKET 4 PERCENT'], label='INCOME 4: > 55000 and <= 75000')
#plt.plot(income_colleges['INCOME BRACKET 5 PERCENT'], label='INCOME 5: > 75000 and <= 95000')
#plt.plot(income_colleges['INCOME BRACKET 6 PERCENT'], label='INCOME 6: > 95000 and <= 115000')
plt.plot(income_colleges['INCOME BRACKET 7 PERCENT'], label='INCOME 7: > 115000 and <= 135000')
#plt.plot(income_colleges['INCOME BRACKET 8 PERCENT'], label='INCOME 8: > 135000 and <= 155000')
#plt.plot(income_colleges['INCOME BRACKET 9 PERCENT'], label='INCOME 9: > 155000 and <= 175000')
plt.plot(income_colleges['INCOME BRACKET 10 PERCENT'], label='INCOME 10: > 175000 and <= 195000')
#plt.plot(income_colleges['INCOME BRACKET 11 PERCENT'], label='INCOME 11: > 195000 and <= 215000')
#plt.plot(income_colleges['INCOME BRACKET 12 PERCENT'], label='INCOME 12: > 215000 and <= 235000')
plt.plot(income_colleges['INCOME BRACKET 13 PERCENT'], label='INCOME 13: > 235000')
plt.legend()
plt.title('Relative College Enrollment as Income Increases')
plt.ylabel('Percent of Students')
plt.xlabel('College Enrollment Status')
plt.xticks([1, 2, 3])


income_math_quints_array = [income1_quint, income2_quint, income3_quint, income4_quint, income5_quint, 
                          income6_quint, income7_quint, income8_quint, income9_quint, income10_quint, 
                          income11_quint, income12_quint, income13_quint]

income_math_quints = pd.DataFrame()
for i in range(len(income_math_quints_array)):
    income_math_quints['INCOME BRACKET ' + str(i + 1)] = income_math_quints_array[i]['X1TXMQUINT']
    income_math_quints['INCOME BRACKET ' + str(i + 1) + ' PERCENT'] = income_math_quints_array[i]['PERCENT']
    
plt.figure(2, figsize=(10, 8), dpi=80)
plt.plot(income_math_quints['INCOME BRACKET 1 PERCENT'], label='INCOME 1: <= 15000')
#plt.plot(income_math_quints['INCOME BRACKET 2 PERCENT'], label='INCOME 2: > 15000 and <= 35000')
#plt.plot(income_math_quints['INCOME BRACKET 3 PERCENT'], label='INCOME 3: > 35000 and <= 55000')
plt.plot(income_math_quints['INCOME BRACKET 4 PERCENT'], label='INCOME 4: > 55000 and <= 75000')
#plt.plot(income_math_quints['INCOME BRACKET 5 PERCENT'], label='INCOME 5: > 75000 and <= 95000')
#plt.plot(income_math_quints['INCOME BRACKET 6 PERCENT'], label='INCOME 6: > 95000 and <= 115000')
plt.plot(income_math_quints['INCOME BRACKET 7 PERCENT'], label='INCOME 7: > 115000 and <= 135000')
#plt.plot(income_math_quints['INCOME BRACKET 8 PERCENT'], label='INCOME 8: > 135000 and <= 155000')
#plt.plot(income_math_quints['INCOME BRACKET 9 PERCENT'], label='INCOME 9: > 155000 and <= 175000')
plt.plot(income_math_quints['INCOME BRACKET 10 PERCENT'], label='INCOME 10: > 175000 and <= 195000')
#plt.plot(income_math_quints['INCOME BRACKET 11 PERCENT'], label='INCOME 11: > 195000 and <= 215000')
#plt.plot(income_math_quints['INCOME BRACKET 12 PERCENT'], label='INCOME 12: > 215000 and <= 235000')
plt.plot(income_math_quints['INCOME BRACKET 13 PERCENT'], label='INCOME 13: > 235000')
plt.legend()
plt.title('Student Mathematics Quintile as Income Increases')
plt.ylabel('Percent of Students')
plt.xlabel('Mathematics Quintile')
plt.xticks([1, 2, 3, 4, 5])
# Out:
# ([<matplotlib.axis.XTick at 0x7f9c4116e730>,
#   <matplotlib.axis.XTick at 0x7f9c4116e700>,
#   <matplotlib.axis.XTick at 0x7f9c41169280>,
#   <matplotlib.axis.XTick at 0x7f9ccf47c2e0>,
#   <matplotlib.axis.XTick at 0x7f9ccf4729a0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ### Conclusions
# There is a clear positive correlation between income and academic performance. People of higher income are more likely to have a higher mathematics quintile score, general mathematics proficiency, overall high school GPA, and chance of enrolling in college full-time.

# %% [markdown]
# ### Possible hypotheses explaining correlations
# - High family income provides social stability for the student.
#     - No need to take on full- or part-time jobs.
#     - Better social influences and environmental factors. Influence of drugs and alcohol from parents may be greatly reduced. Likely to grow up in affluent neighborhoods and enroll in good school districts.
#     - Free time allows the student to engage with friends and extracurricular activities. Improves academic and social efficacy.
#     - Ability to afford extracurricular enrichment. e.g. music, academic tutoring, traveling and community service abroad.
# - Greater ability to afford college tuition.

# %% [markdown]
# ## Academic Measures by Poverty: Math, GPA, and College Attendance<a id='measuresByPoverty'></a>

# %% [markdown]
# ### Constants and Functions

# %%
# Takes in poverty_num from X1POVERTY column. Returns math performance table, 
# math quintile counts, GPA counts, and college status counts
def analyze_poverty(poverty_num):
    poverty = indicators[indicators['X1POVERTY'] == poverty_num]
    poverty_academic = poverty[academic_variables]
    
    poverty_cont = poverty_academic[math_cont_variables].describe()
    
    poverty_quint = poverty_academic[math_quintile].value_counts().to_frame()
    num_drop = len([i for i in poverty_quint.index if i < 0])
    poverty_quint = poverty_quint.sort_index().iloc[num_drop:]
    poverty_quint['PERCENT'] = poverty_quint[math_quintile] / poverty_quint[math_quintile].sum() * 100
    
    poverty_gpa = poverty_academic[gpa_variable].value_counts().to_frame()
    num_drop = len([i for i in poverty_gpa.index if i < 0])
    poverty_gpa = poverty_gpa.sort_index().iloc[num_drop:]
    poverty_gpa['PERCENT'] = poverty_gpa[gpa_variable] / poverty_gpa[gpa_variable].sum() * 100
    
    poverty_college = poverty_academic[college_variable].value_counts().to_frame()
    num_drop = len([i for i in poverty_college.index if i < 0])
    poverty_college = poverty_college.sort_index().iloc[num_drop:]
    poverty_college['PERCENT'] = poverty_college[college_variable] / poverty_college[college_variable].sum() * 100
    
    return poverty_cont, poverty_quint, poverty_gpa, poverty_college

# %% [markdown]
# ### Above Poverty Level (relative to 100% of census poverty threshold)

# %%
above_poverty_cont, above_poverty_quint, above_poverty_gpa, above_poverty_college = analyze_poverty(0)
print(above_poverty_cont, '\n\n', above_poverty_quint, '\n\n', above_poverty_gpa, '\n\n', above_poverty_college)
# Out:
#             X1TXMTH      X1TXMSCR    X1TXMPROF1    X1TXMPROF2    X1TXMPROF3  \
# count  14062.000000  14062.000000  14062.000000  14062.000000  14062.000000
# mean       0.085507     41.672833      0.763411      0.548367      0.375580
# std        1.411389     13.308695      1.159410      1.158255      1.147599
# min       -8.000000     -8.000000     -8.000000     -8.000000     -8.000000
# 25%       -0.389525     34.361525      0.959100      0.440150      0.144625
# 50%        0.175650     42.447400      0.995700      0.821700      0.461250
# 75%        0.878525     51.066975      0.999800      0.971000      0.913775
# max        3.028300     69.931700      1.000000      1.000000      1.000000
#
#          X1TXMPROF4    X1TXMPROF5
# count  14062.000000  14062.000000
# mean       0.108152     -0.017839
# std        1.089387      1.048097
# min       -8.000000     -8.000000
# 25%        0.054500      0.050325
# 50%        0.095800      0.059700
# 75%        0.343250      0.107400
# max        0.998200      0.979600
#
#     X1TXMQUINT    PERCENT
# 1        1689  12.214348
# 2        2169  15.685566
# 3        2685  19.417125
# 4        3285  23.756147
# 5        4000  28.926815
#
#     S4HSGPA    PERCENT
# 1      228  13.701923
# 2      450  27.043269
# 3      203  12.199519
# 4      391  23.497596
# 5      149   8.954327
# 6      145   8.713942
# 7       52   3.125000
# 8       46   2.764423
#
#     S3CLGFT    PERCENT
# 1     8710  89.636719
# 2      610   6.277658
# 3      397   4.085623

# %% [markdown]
# ### Below Poverty Threshold (relative to 100% of census poverty threshold)

# %%
below_poverty_cont, below_poverty_quint, below_poverty_gpa, below_poverty_college = analyze_poverty(1)
print(below_poverty_cont, '\n\n', below_poverty_quint, '\n\n', below_poverty_gpa, '\n\n', below_poverty_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  2671.000000  2671.000000  2671.000000  2671.000000  2671.000000
# mean     -0.553240    34.204887     0.576512     0.271519     0.087437
# std       1.504024    12.797529     1.438188     1.399756     1.361033
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -0.983100    26.003550     0.717100     0.111800     0.052200
# 50%      -0.330200    35.274000     0.967300     0.491000     0.164100
# 75%       0.148700    42.098900     0.995200     0.810250     0.440000
# max       3.028300    69.931700     1.000000     1.000000     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  2671.000000  2671.000000
# mean     -0.093207    -0.141210
# std       1.307857     1.291665
# min      -8.000000    -8.000000
# 25%       0.042300     0.047400
# 50%       0.056800     0.050900
# 75%       0.092350     0.058950
# max       0.998200     0.979600
#
#     X1TXMQUINT    PERCENT
# 1         689  26.489812
# 2         644  24.759708
# 3         580  22.299116
# 4         441  16.955017
# 5         247   9.496348
#
#     S4HSGPA    PERCENT
# 1       31   5.496454
# 2       95  16.843972
# 3       53   9.397163
# 4      186  32.978723
# 5       65  11.524823
# 6       65  11.524823
# 7       26   4.609929
# 8       43   7.624113
#
#     S3CLGFT    PERCENT
# 1      850  73.212748
# 2      169  14.556417
# 3      142  12.230835

# %%
poverty_gpas_array = [above_poverty_gpa, below_poverty_gpa]

poverty_gpas = pd.DataFrame()
for i in range(len(poverty_gpas_array)):
    poverty_gpas['POVERTY LEVEL ' + str(i)] = poverty_gpas_array[i]['S4HSGPA']
    poverty_gpas['POVERTY LEVEL ' + str(i) + ' PERCENT'] = poverty_gpas_array[i]['PERCENT'] 
poverty_gpas.fillna(0, inplace=True)

plt.figure(3)
plt.plot(poverty_gpas['POVERTY LEVEL 0 PERCENT'], label='ABOVE POVERTY LEVEL')
plt.plot(poverty_gpas['POVERTY LEVEL 1 PERCENT'], label='BELOW POVERTY LEVEL')
plt.legend()
plt.title('Relative Grades Earned Based on Poverty Level (relative to 100% of census poverty threshold)')
plt.ylabel('Percent of Students')
plt.xlabel('Grade')


poverty_colleges_array = [above_poverty_college, below_poverty_college]

poverty_colleges = pd.DataFrame()
for i in range(len(poverty_colleges_array)):
    poverty_colleges['POVERTY LEVEL ' + str(i)] = poverty_colleges_array[i]['S3CLGFT']
    poverty_colleges['POVERTY LEVEL ' + str(i) + ' PERCENT'] = poverty_colleges_array[i]['PERCENT']
poverty_colleges.fillna(0, inplace=True)

plt.figure(4)
plt.plot(poverty_colleges['POVERTY LEVEL 0 PERCENT'], label='ABOVE POVERTY LEVEL')
plt.plot(poverty_colleges['POVERTY LEVEL 1 PERCENT'], label='BELOW POVERTY LEVEL')
plt.legend()
plt.title('College Enrollment Based on Poverty Level (relative to 100% of census poverty threshold)')
plt.ylabel('Percent of Students')
plt.xlabel('College Enrollment Status')
plt.xticks([1, 2, 3])


poverty_math_quints_array = [above_poverty_quint, below_poverty_quint]

poverty_math_quints = pd.DataFrame()
for i in range(len(poverty_math_quints_array)):
    poverty_math_quints['POVERTY LEVEL ' + str(i)] = poverty_math_quints_array[i]['X1TXMQUINT']
    poverty_math_quints['POVERTY LEVEL ' + str(i) + ' PERCENT'] = poverty_math_quints_array[i]['PERCENT']
    
plt.figure(5)
plt.plot(poverty_math_quints['POVERTY LEVEL 0 PERCENT'], label='ABOVE POVERTY LEVEL')
plt.plot(poverty_math_quints['POVERTY LEVEL 1 PERCENT'], label='BELOW POVERTY LEVEL')
plt.legend()
plt.title('Student Mathmatics Quintile Based on Poverty Level (relative to 100% of census poverty threshold)')
plt.ylabel('Percent of Students')
plt.xlabel('Mathematics Quintile')
plt.xticks([1, 2, 3, 4, 5])
# Out:
# ([<matplotlib.axis.XTick at 0x7f9c5416cf10>,
#   <matplotlib.axis.XTick at 0x7f9c5416cee0>,
#   <matplotlib.axis.XTick at 0x7f9c54173a60>,
#   <matplotlib.axis.XTick at 0x7f9c541781f0>,
#   <matplotlib.axis.XTick at 0x7f9c549c0490>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# ## Academic Measures by Race: Math, GPA, and College Attendance<a id='measuresByRace'></a>

# %% [markdown]
# ### Constants and Functions

# %%
def analyze_race(race_num):
    race = indicators[indicators['X1RACE'] == race_num]
    race_academic = race[academic_variables]
    
    race_cont = race_academic[math_cont_variables].describe()
    
    race_quint = race_academic[math_quintile].value_counts().to_frame()
    num_drop = len([i for i in race_quint.index if i < 0])
    race_quint = race_quint.sort_index().iloc[num_drop:]
    race_quint['PERCENT'] = race_quint[math_quintile] / race_quint[math_quintile].sum() * 100
    
    race_gpa = race_academic[gpa_variable].value_counts().to_frame()
    num_drop = len([i for i in race_gpa.index if i < 0])
    race_gpa = race_gpa.sort_index().iloc[num_drop:]
    race_gpa['PERCENT'] = race_gpa[gpa_variable] / race_gpa[gpa_variable].sum() * 100
    
    race_college = race_academic[college_variable].value_counts().to_frame()
    num_drop = len([i for i in race_college.index if i < 0])
    race_college = race_college.sort_index().iloc[num_drop:]
    race_college['PERCENT'] = race_college[college_variable] / race_college[college_variable].sum() * 100
    
    return race_cont, race_quint, race_gpa, race_college

# %% [markdown]
# ### American Indian / Alaskan Native

# %%
native_cont, native_quint, native_gpa, native_college = analyze_race(1)
print(native_cont, '\n\n', native_quint, '\n\n', native_gpa, '\n\n', native_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  165.000000  165.000000  165.000000  165.000000  165.000000  165.000000
# mean    -0.674155   32.330358    0.580452    0.313629    0.177008    0.023982
# std      1.324268   13.189816    1.026775    0.995436    0.964296    0.910211
# min     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 25%     -1.586400   20.182900    0.220500    0.036900    0.032600    0.038400
# 50%     -0.527800   32.231400    0.932000    0.327200    0.109000    0.050200
# 75%      0.181400   42.522100    0.995800    0.824100    0.465900    0.096600
# max      1.874700   62.517300    1.000000    0.998500    0.998700    0.926900
#
#        X1TXMPROF5
# count  165.000000
# mean    -0.026690
# std      0.888733
# min     -8.000000
# 25%      0.046500
# 50%      0.049300
# 75%      0.059900
# max      0.501500
#
#     X1TXMQUINT    PERCENT
# 1          63  38.650307
# 2          38  23.312883
# 3          19  11.656442
# 4          27  16.564417
# 5          16   9.815951
#
#     S4HSGPA    PERCENT
# 1        2   5.555556
# 2        9  25.000000
# 3        2   5.555556
# 4       11  30.555556
# 5        4  11.111111
# 6        2   5.555556
# 7        3   8.333333
# 8        3   8.333333
#
#     S3CLGFT    PERCENT
# 1       52  77.611940
# 2        9  13.432836
# 3        6   8.955224

# %% [markdown]
# ### Asian, non-Hispanic

# %%
asian_cont, asian_quint, asian_gpa, asian_college = analyze_race(2)
print(asian_cont, '\n\n', asian_quint, '\n\n', asian_gpa, '\n\n', asian_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  1952.000000  1952.000000  1952.000000  1952.000000  1952.000000
# mean     -0.543958    40.253318    -0.334779    -0.452498    -0.566719
# std       3.195758    22.772031     3.141525     3.100211     3.059911
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -0.403600    34.144000     0.956850     0.428125     0.140400
# 50%       0.499650    46.495150     0.998900     0.919500     0.718800
# 75%       1.314425    56.219325     1.000000     0.991800     0.984725
# max       3.028300    69.931700     1.000000     1.000000     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  1952.000000  1952.000000
# mean     -0.803455    -0.970459
# std       2.963380     2.885599
# min      -8.000000    -8.000000
# 25%       0.054000     0.050200
# 50%       0.163250     0.073050
# 75%       0.671150     0.204975
# max       0.998200     0.979600
#
#     X1TXMQUINT    PERCENT
# 1         117   6.997608
# 2         141   8.433014
# 3         227  13.576555
# 4         376  22.488038
# 5         811  48.504785
#
#     S4HSGPA    PERCENT
# 1       41  19.248826
# 2       81  38.028169
# 3       28  13.145540
# 4       46  21.596244
# 5        6   2.816901
# 6        2   0.938967
# 7        2   0.938967
# 8        7   3.286385
#
#     S3CLGFT    PERCENT
# 1     1223  90.058910
# 2       83   6.111929
# 3       52   3.829161

# %% [markdown]
# ### Black/African-American, non-Hispanic

# %%
black_cont, black_quint, black_gpa, black_college = analyze_race(3)
print(black_cont, '\n\n', black_quint, '\n\n', black_gpa, '\n\n', black_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  2450.000000  2450.000000  2450.000000  2450.000000  2450.000000
# mean     -1.135866    30.498397    -0.047497    -0.334569    -0.492833
# std       2.377148    16.251161     2.589256     2.502482     2.446086
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -1.315600    22.478600     0.434300     0.058500     0.037900
# 50%      -0.507650    32.539650     0.936750     0.342650     0.113450
# 75%       0.097225    41.423300     0.994000     0.786475     0.400525
# max       3.028300    69.931700     1.000000     1.000000     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  2450.000000  2450.000000
# mean     -0.654179    -0.697716
# std       2.380819     2.362754
# min      -8.000000    -8.000000
# 25%       0.039600     0.046800
# 50%       0.050800     0.049450
# 75%       0.086300     0.057600
# max       0.998200     0.979600
#
#     X1TXMQUINT    PERCENT
# 1         678  30.568079
# 2         539  24.301172
# 3         425  19.161407
# 4         368  16.591524
# 5         208   9.377818
#
#     S4HSGPA    PERCENT
# 1       18   3.789474
# 2      110  23.157895
# 3       56  11.789474
# 4      157  33.052632
# 5       69  14.526316
# 6       38   8.000000
# 7       13   2.736842
# 8       14   2.947368
#
#     S3CLGFT    PERCENT
# 1     1073  81.970970
# 2      134  10.236822
# 3      102   7.792208

# %% [markdown]
# ### Hispanic, no race specified

# %%
hispanicnr_cont, hispanicnr_quint, hispanicnr_gpa, hispanicnr_college = analyze_race(4)
print(hispanicnr_cont, '\n\n', hispanicnr_quint, '\n\n', hispanicnr_gpa, '\n\n', hispanicnr_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  422.000000  422.000000  422.000000  422.000000  422.000000  422.000000
# mean    -4.356218   12.347547   -3.758284   -3.911678   -4.002137   -4.079524
# std      3.823502   22.387430    4.395938    4.238036    4.142548    4.059164
# min     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 25%     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 50%     -8.000000   -8.000000   -8.000000   -8.000000   -8.000000   -8.000000
# 75%     -0.419625   33.896050    0.954200    0.414550    0.135800    0.053450
# max      1.857400   62.336300    1.000000    0.998400    0.998600    0.923000
#
#        X1TXMPROF5
# count  422.000000
# mean    -4.100201
# std      4.036429
# min     -8.000000
# 25%     -8.000000
# 50%     -8.000000
# 75%      0.050100
# max      0.489700
#
#     X1TXMQUINT    PERCENT
# 1          64  31.372549
# 2          48  23.529412
# 3          51  25.000000
# 4          22  10.784314
# 5          19   9.313725
#
#     S4HSGPA  PERCENT
# 1        2     2.50
# 2       15    18.75
# 3       12    15.00
# 4       18    22.50
# 5        9    11.25
# 6       15    18.75
# 7        2     2.50
# 8        7     8.75
#
#     S3CLGFT    PERCENT
# 1      116  73.417722
# 2       28  17.721519
# 3       14   8.860759

# %% [markdown]
# ### Hispanic, race specified

# %%
hispanicrs_cont, hispanicrs_quint, hispanicrs_gpa, hispanicrs_college = analyze_race(5)
print(hispanicrs_cont, '\n\n', hispanicrs_quint, '\n\n', hispanicrs_gpa, '\n\n', hispanicrs_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  3375.000000  3375.000000  3375.000000  3375.000000  3375.000000
# mean     -0.378327    36.024284     0.665346     0.379217     0.194223
# std       1.385640    12.649624     1.237355     1.215879     1.185353
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -0.859100    27.530350     0.798900     0.147350     0.061600
# 50%      -0.204200    37.182500     0.979900     0.595100     0.215400
# 75%       0.341500    44.546400     0.997800     0.880200     0.596550
# max       3.028300    69.931700     1.000000     1.000000     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  3375.000000  3375.000000
# mean     -0.012537    -0.078248
# std       1.126078     1.103901
# min      -8.000000    -8.000000
# 25%       0.043800     0.047800
# 50%       0.062700     0.052300
# 75%       0.123450     0.065350
# max       0.998200     0.979600
#
#     X1TXMQUINT    PERCENT
# 1         769  23.225612
# 2         720  21.745696
# 3         745  22.500755
# 4         627  18.936877
# 5         450  13.591060
#
#     S4HSGPA    PERCENT
# 1       34   6.250000
# 2      121  22.242647
# 3       65  11.948529
# 4      184  33.823529
# 5       51   9.375000
# 6       48   8.823529
# 7       18   3.308824
# 8       23   4.227941
#
#     S3CLGFT    PERCENT
# 1     1335  77.933450
# 2      237  13.835377
# 3      141   8.231173

# %% [markdown]
# ### More than one race, non-Hispanic

# %%
more_cont, more_quint, more_gpa, more_college = analyze_race(6)
print(more_cont, '\n\n', more_quint, '\n\n', more_gpa, '\n\n', more_college)
# Out:
#            X1TXMTH     X1TXMSCR   X1TXMPROF1   X1TXMPROF2   X1TXMPROF3  \
# count  1941.000000  1941.000000  1941.000000  1941.000000  1941.000000
# mean     -0.083629    39.475109     0.757681     0.506351     0.320087
# std       1.330947    12.697404     1.102975     1.100132     1.082910
# min      -8.000000    -8.000000    -8.000000    -8.000000    -8.000000
# 25%      -0.549700    31.897600     0.926500     0.310800     0.104400
# 50%       0.006200    40.196400     0.991300     0.738400     0.335500
# 75%       0.660000    48.443700     0.999400     0.947200     0.820700
# max       3.028300    69.931700     1.000000     1.000000     1.000000
#
#         X1TXMPROF4   X1TXMPROF5
# count  1941.000000  1941.000000
# mean      0.070437    -0.025724
# std       1.021230     0.988820
# min      -8.000000    -8.000000
# 25%       0.049700     0.049200
# 50%       0.077300     0.055700
# 75%       0.222700     0.084200
# max       0.998200     0.979600
#
#     X1TXMQUINT    PERCENT
# 1         294  15.376569
# 2         354  18.514644
# 3         421  22.018828
# 4         434  22.698745
# 5         409  21.391213
#
#     S4HSGPA    PERCENT
# 1       29   9.764310
# 2       71  23.905724
# 3       31  10.437710
# 4       76  25.589226
# 5       30  10.101010
# 6       40  13.468013
# 7        7   2.356902
# 8       13   4.377104
#
#     S3CLGFT    PERCENT
# 1      903  86.081983
# 2       83   7.912297
# 3       63   6.005720

# %% [markdown]
# ### Native Hawaiian / Pacific Islander, non-Hispanic

# %%
pacific_cont, pacific_quint, pacific_gpa, pacific_college = analyze_race(7)
print(pacific_cont, '\n\n', pacific_quint, '\n\n', pacific_gpa, '\n\n', pacific_college)
# Out:
#           X1TXMTH    X1TXMSCR  X1TXMPROF1  X1TXMPROF2  X1TXMPROF3  X1TXMPROF4  \
# count  110.000000  110.000000  110.000000  110.000000  110.000000  110.000000
# mean    -0.145075   38.048846    0.834285    0.582538    0.398238    0.160746
# std      0.953694   11.729443    0.290357    0.359211    0.344430    0.200474
# min     -2.439300   16.163900    0.011700    0.011500    0.027400    0.036800
# 25%     -0.687400   29.861775    0.882175    0.222475    0.080975    0.046625
# 50%     -0.066000   39.188400    0.988400    0.694000    0.289650    0.071500
# 75%      0.468675   46.115850    0.998675    0.912875    0.696150    0.154200
# max      2.457200   67.471000    1.000000    0.999700    0.999900    0.988400
#
#        X1TXMPROF5
# count  110.000000
# mean     0.081235
# std      0.091306
# min      0.046200
# 25%      0.048400
# 50%      0.054350
# 75%      0.071325
# max      0.855900
#
#     X1TXMQUINT    PERCENT
# 1          25  22.727273
# 2          18  16.363636
# 3          25  22.727273
# 4          23  20.909091
# 5          19  17.272727
#
#     S4HSGPA    PERCENT
# 1        2  10.526316
# 2        4  21.052632
# 3        1   5.263158
# 4        6  31.578947
# 5        1   5.263158
# 6        1   5.263158
# 7        4  21.052632
#
#     S3CLGFT    PERCENT
# 1       42  80.769231
# 2        6  11.538462
# 3        4   7.692308

# %% [markdown]
# ### White, non-Hispanic

# %%
white_cont, white_quint, white_gpa, white_college = analyze_race(8)
print(white_cont, '\n\n', white_quint, '\n\n', white_gpa, '\n\n', white_college)
# Out:
#             X1TXMTH      X1TXMSCR    X1TXMPROF1    X1TXMPROF2    X1TXMPROF3  \
# count  12082.000000  12082.000000  12082.000000  12082.000000  12082.000000
# mean      -0.035802     40.315577      0.729746      0.500011      0.321638
# std        1.440503     13.274927      1.232168      1.224499      1.207824
# min       -8.000000     -8.000000     -8.000000     -8.000000     -8.000000
# 25%       -0.484750     32.891725      0.941825      0.360825      0.118825
# 50%        0.082450     41.227300      0.993700      0.779250      0.389500
# 75%        0.769075     49.756425      0.999600      0.960700      0.873600
# max        3.028300     69.931700      1.000000      1.000000      1.000000
#
#          X1TXMPROF4    X1TXMPROF5
# count  12082.000000  12082.000000
# mean       0.061668     -0.049978
# std        1.145705      1.108960
# min       -8.000000     -8.000000
# 25%        0.051425      0.049600
# 50%        0.084700      0.057300
# 75%        0.276875      0.094400
# max        0.998200      0.979600
#
#     X1TXMQUINT    PERCENT
# 1        1656  13.969968
# 2        2046  17.259997
# 3        2410  20.330690
# 4        2770  23.367640
# 5        2972  25.071706
#
#     S4HSGPA    PERCENT
# 1      183  12.348178
# 2      324  21.862348
# 3      170  11.470985
# 4      348  23.481781
# 5      148   9.986505
# 6      179  12.078273
# 7       68   4.588394
# 8       62   4.183536
#
#     S3CLGFT    PERCENT
# 1     6484  89.496204
# 2      444   6.128364
# 3      317   4.375431

# %%
race_gpas_array = [native_gpa, asian_gpa, black_gpa, hispanicnr_gpa, hispanicrs_gpa, more_gpa, pacific_gpa, white_gpa]

race_gpas = pd.DataFrame()
for i in range(len(race_gpas_array)):
    race_gpas['RACE ' + str(i+1)] = race_gpas_array[i]['S4HSGPA']
    race_gpas['RACE ' + str(i+1) + ' PERCENT'] = race_gpas_array[i]['PERCENT'] 
race_gpas.fillna(0, inplace=True)

plt.figure(num=6, figsize=(10, 8), dpi=80)
plt.plot(race_gpas['RACE 1 PERCENT'], label='American Indian/Alaska Native, non-Hispanic')
plt.plot(race_gpas['RACE 2 PERCENT'], label='Asian, non-hispanic')
plt.plot(race_gpas['RACE 3 PERCENT'], label='Black/African-American, non-Hispanic')
plt.plot(race_gpas['RACE 4 PERCENT'], label='Hispanic, no race specified')
plt.plot(race_gpas['RACE 5 PERCENT'], label='Hispanic, race specified')
plt.plot(race_gpas['RACE 6 PERCENT'], label='More than one race, non-Hispanic')
plt.plot(race_gpas['RACE 7 PERCENT'], label='Hative Hawaiian/Pacific Islander, non-Hispanic')
plt.plot(race_gpas['RACE 8 PERCENT'], label='White, non-Hispanic')
plt.legend()
plt.title('Relative Grades Earned Based on Race')
plt.ylabel('Percent of Students')
plt.xlabel('Grade')


race_colleges_array = [native_college, asian_college, black_college, hispanicnr_college, hispanicrs_college, 
                       more_college, pacific_college, white_college]

race_colleges = pd.DataFrame()
for i in range(len(race_colleges_array)):
    race_colleges['RACE ' + str(i+1)] = race_colleges_array[i]['S3CLGFT']
    race_colleges['RACE ' + str(i+1) + ' PERCENT'] = race_colleges_array[i]['PERCENT'] 
race_colleges.fillna(0, inplace=True)

plt.figure(7, figsize=(10, 8), dpi=80)
plt.plot(race_colleges['RACE 1 PERCENT'], label='American Indian/Alaska Native, non-Hispanic')
plt.plot(race_colleges['RACE 2 PERCENT'], label='Asian, non-hispanic')
plt.plot(race_colleges['RACE 3 PERCENT'], label='Black/African-American, non-Hispanic')
plt.plot(race_colleges['RACE 4 PERCENT'], label='Hispanic, no race specified')
plt.plot(race_colleges['RACE 5 PERCENT'], label='Hispanic, race specified')
plt.plot(race_colleges['RACE 6 PERCENT'], label='More than one race, non-Hispanic')
plt.plot(race_colleges['RACE 7 PERCENT'], label='Hative Hawaiian/Pacific Islander, non-Hispanic')
plt.plot(race_colleges['RACE 8 PERCENT'], label='White, non-Hispanic')
plt.legend()
plt.title('College Enrollment Based on Race')
plt.ylabel('Percent of Students')
plt.xlabel('College Enrollment Status')
plt.xticks([1, 2, 3])


race_math_quints_array = [native_quint, asian_quint, black_quint, hispanicnr_quint, hispanicrs_quint, 
                       more_quint, pacific_quint, white_quint]

race_math_quints = pd.DataFrame()
for i in range(len(race_math_quints_array)):
    race_math_quints['RACE ' + str(i+1)] = race_math_quints_array[i]['X1TXMQUINT']
    race_math_quints['RACE ' + str(i+1) + ' PERCENT'] = race_math_quints_array[i]['PERCENT'] 
race_math_quints.fillna(0, inplace=True)

plt.figure(8, figsize=(10, 8), dpi=80)
plt.plot(race_math_quints['RACE 1 PERCENT'], label='American Indian/Alaska Native, non-Hispanic')
plt.plot(race_math_quints['RACE 2 PERCENT'], label='Asian, non-hispanic')
plt.plot(race_math_quints['RACE 3 PERCENT'], label='Black/African-American, non-Hispanic')
plt.plot(race_math_quints['RACE 4 PERCENT'], label='Hispanic, no race specified')
plt.plot(race_math_quints['RACE 5 PERCENT'], label='Hispanic, race specified')
plt.plot(race_math_quints['RACE 6 PERCENT'], label='More than one race, non-Hispanic')
plt.plot(race_math_quints['RACE 7 PERCENT'], label='Hative Hawaiian/Pacific Islander, non-Hispanic')
plt.plot(race_math_quints['RACE 8 PERCENT'], label='White, non-Hispanic')
plt.legend()
plt.title('Student Mathematics Quintile Based on Race')
plt.ylabel('Percent of Students')
plt.xlabel('Mathematics Quintile')
plt.xticks([1, 2, 3, 4, 5])
# Out:
# ([<matplotlib.axis.XTick at 0x7f9baa259610>,
#   <matplotlib.axis.XTick at 0x7f9baa2595e0>,
#   <matplotlib.axis.XTick at 0x7f9baa256430>,
#   <matplotlib.axis.XTick at 0x7f9baa2b1070>,
#   <matplotlib.axis.XTick at 0x7f9baa2b1580>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
