# %% [markdown]
# # Household Pulse Survey Phase 1 Data Analysis
# - UrsaMinor Jupyter Notebook
# - 17 November 2020
# - By Barnett Yang

# %% [markdown]
# ## Goals
# - Analyze reductions in income and increase in poverty by race due to the COVID-19 pandemic.
# - Relate such correlations to reductions in academic performance by race and income.

# %% [markdown]
# ## Indicators and Relevant Variables

# %% [markdown]
# ### Demographics
# - RHISPANIC: Hispanic Origin
#     - 1: No, not of Hispanic, Latino, or Spanish origin
#     - 2: Yes, or Hispanic, Latino, or Spanish origin
# - RRACE: Race
#     - 1: White, Alone
#     - 2: Black, Alone
#     - 3: Asian, Alone
#     - 4: Any other race alone, or race in combination
# - EEDUC: Educational attainment
#     - 1: Less than high school
#     - 2: Some high school
#     - 3: High school graduate or equivalent (e.g. GED)
#     - 4: Some college, but degree not received or is in process
#     - 5: Associate's degree (e.g. AA, AS)
#     - 6: Bachelor's degree (e.g. BA, BS, AB)
#     - 7: Graduate degree (e.g. master's, professional, doctorate)

# %% [markdown]
# ### Income and Economic Prosperity Variables
# - WRKLOSS: Recent household job loss
#     - 1: Yes
#     - 2: No
# - EXPCTLOSS: Expected household job loss
#     - 1: Yes
#     - 2: No
# - ANYWORK: Employment status for last 7 days
#     - 1: Yes
#     - 2: No
# - INCOME: Total household income (before taxes, in US dollars 2020)
#     - 1: Less than 25000
#     - 2: 25000 - 34999
#     - 3: 35000 - 49999
#     - 4: 50000 - 74999
#     - 6: 100000 - 149999
#     - 7: 150000 - 199999
#     - 8: 200000 and above

# %% [markdown]
# ## Miscellaneous Notes and Libraries
# The data can be found at https://www.census.gov/programs-surveys/household-pulse-survey/datasets.html.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Upload Raw Data

# %% [markdown]
# ### Week 1: April 23 - May 5

# %%
week1 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week01_PUF_CSV/pulse2020_puf_01.csv')

# %% [markdown]
# ### Week 2: May 7 - May 12

# %%
week2 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week02_PUF_CSV/pulse2020_puf_02.csv')

# %% [markdown]
# ### Week 3: May 14 - May 19

# %%
week3 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week03_PUF_CSV/pulse2020_puf_03.csv')

# %% [markdown]
# ### Week 4: May 21 - May 26

# %%
week4 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week04_PUF_CSV/pulse2020_puf_04.csv')

# %% [markdown]
# ### Week 5: May 28 - June 2

# %%
week5 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week05_PUF_CSV/pulse2020_puf_05.csv')

# %% [markdown]
# ### Week 6: June 4 - June 9

# %%
week6 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week06_PUF_CSV/pulse2020_puf_06.csv')

# %% [markdown]
# ### Week 7: June 11 - June 16

# %%
week7 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week07_PUF_CSV/pulse2020_puf_07.csv')

# %% [markdown]
# ### Week 8: June 18 - June 23

# %%
week8 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week08_PUF_CSV/pulse2020_puf_08.csv')

# %% [markdown]
# ### Week 9: June 25 - June 30

# %%
week9 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week09_PUF_CSV/pulse2020_puf_09.csv')

# %% [markdown]
# ### Week 10: July 2 - July 7

# %%
week10 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week10_PUF_CSV/pulse2020_puf_10.csv')

# %% [markdown]
# ### Week 11: July 9 - July 14

# %%
week11 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week11_PUF_CSV/pulse2020_puf_11.csv')

# %% [markdown]
# ### Week 12: July 16 - July 21

# %%
week12 = pd.read_csv('../data/Household_Pulse_Survey_Phase_1/HPS_Week12_PUF_CSV/pulse2020_puf_12.csv')

# %% [markdown]
# ## Changes in Income Over the Course of the COVID-19 Pandemic Based on Race

# %% [markdown]
# ### Constants and Functions, Filter only Relevant Indicators

# %%
indicators = ['RHISPANIC', 'RRACE', 'EEDUC', 'WRKLOSS', 'EXPCTLOSS', 'ANYWORK', 'INCOME']
eco_indicators = ['WRKLOSS', 'EXPCTLOSS', 'ANYWORK', 'INCOME']

week1 = week1[indicators]
week2 = week2[indicators]
week3 = week3[indicators]
week4 = week4[indicators]
week5 = week5[indicators]
week6 = week6[indicators]
week7 = week7[indicators]
week8 = week8[indicators]
week9 = week9[indicators]
week10 = week10[indicators]
week11 = week11[indicators]
week12 = week12[indicators]

phase1 = [week1, week2, week3, week4, week5, week6, week7, week8, week9, week10, week11, week12]

# %% [markdown]
# ### Hispanic

# %%
hispanic_income = pd.DataFrame()

for i in range(len(phase1)):
    week = phase1[i][phase1[i]['RHISPANIC'] == 2]
    
    week_income = week['INCOME'].value_counts().to_frame()
    num_drop = len([i for i in week_income.index if i < 0])
    week_income = week_income.sort_index().iloc[num_drop:]
    week_income['PERCENT'] = week_income['INCOME'] / week_income['INCOME'].sum() * 100
    
    hispanic_income['WEEK ' + str(i + 1) + ' INCOME'] = week_income['INCOME']
    hispanic_income['WEEK ' + str(i + 1) + ' PERCENT'] = week_income['PERCENT']
    
print(hispanic_income)
# Out:
#    WEEK 1 INCOME  WEEK 1 PERCENT  WEEK 2 INCOME  WEEK 2 PERCENT  \
# 1            895       17.341600            479       17.552217
# 2            691       13.388878            350       12.825211
# 3            771       14.938965            416       15.243679
# 4            930       18.019764            465       17.039209
# 5            642       12.439450            347       12.715280
# 6            669       12.962604            357       13.081715
# 7            290        5.619066            167        6.119458
# 8            273        5.289673            148        5.423232
#
#    WEEK 3 INCOME  WEEK 3 PERCENT  WEEK 4 INCOME  WEEK 4 PERCENT  \
# 1           1606       16.992911           1070       16.456475
# 2           1219       12.898106            813       12.503845
# 3           1253       13.257856            889       13.672716
# 4           1773       18.759920           1119       17.210089
# 5           1211       12.813459            850       13.072901
# 6           1320       13.966776            915       14.072593
# 7            499        5.279865            402        6.182713
# 8            570        6.031108            444        6.828668
#
#    WEEK 5 INCOME  WEEK 5 PERCENT  ...  WEEK 8 INCOME  WEEK 8 PERCENT  \
# 1           1332       17.905632  ...           1550       18.252473
# 2            963       12.945288  ...           1170       13.777673
# 3           1017       13.671192  ...           1215       14.307584
# 4           1283       17.246942  ...           1498       17.640132
# 5            977       13.133486  ...           1016       11.964202
# 6            995       13.375454  ...           1077       12.682525
# 7            449        6.035757  ...            481        5.664154
# 8            423        5.686248  ...            485        5.711258
#
#    WEEK 9 INCOME  WEEK 9 PERCENT  WEEK 10 INCOME  WEEK 10 PERCENT  \
# 1           1402       18.866909            1334        19.389535
# 2           1068       14.372224             911        13.241279
# 3           1085       14.600996             930        13.517442
# 4           1349       18.153681            1249        18.154070
# 5            901       12.124882             866        12.587209
# 6            876       11.788454             871        12.659884
# 7            378        5.086799             336         4.883721
# 8            372        5.006056             383         5.566860
#
#    WEEK 11 INCOME  WEEK 11 PERCENT  WEEK 12 INCOME  WEEK 12 PERCENT
# 1            1262        18.005422            1205        18.098528
# 2             951        13.568269             921        13.832983
# 3             984        14.039093             967        14.523881
# 4            1277        18.219432            1232        18.504055
# 5             940        13.411328             817        12.270952
# 6             845        12.055928             825        12.391108
# 7             385         5.492938             359         5.392010
# 8             365         5.207590             332         4.986482
#
# [8 rows x 24 columns]

# %% [markdown]
# ### Visualizations

# %%
# Useful for changing x-axis labels later
positions = ['WEEK ' + str(i) + ' PERCENT' for i in range(1, 13)]
labels = [i for i in range(1, 13)]

plt.figure(0, figsize=(10, 8), dpi=80)

for i in range(8):
    week = hispanic_income.iloc[i].to_frame()
    week = week[week.index.str.contains('PERCENT')]
    plt.plot(week, label='INCOME BRACKET ' + str(i + 1))
    
plt.xticks(positions, labels)
plt.legend()
plt.xlabel('Number of weeks')
plt.ylabel('Percent population in income bracket')
plt.title('Changes in percent Hispanic population distribution in 8 income brackets')
# Out:
# Text(0.5, 1.0, 'Changes in percent Hispanic population distribution in 8 income brackets')

# %% [markdown]
# ### White

# %%
white_income = pd.DataFrame()

for i in range(len(phase1)):
    week = phase1[i][phase1[i]['RRACE'] == 1]
    
    week_income = week['INCOME'].value_counts().to_frame()
    num_drop = len([i for i in week_income.index if i < 0])
    week_income = week_income.sort_index().iloc[num_drop:]
    week_income['PERCENT'] = week_income['INCOME'] / week_income['INCOME'].sum() * 100
    
    white_income['WEEK ' + str(i + 1) + ' INCOME'] = week_income['INCOME']
    white_income['WEEK ' + str(i + 1) + ' PERCENT'] = week_income['PERCENT']
    
print(white_income)
# Out:
#    WEEK 1 INCOME  WEEK 1 PERCENT  WEEK 2 INCOME  WEEK 2 PERCENT  \
# 1           5612       10.212735           3170        9.872006
# 2           4777        8.693199           2635        8.205911
# 3           5988       10.896981           3414       10.631871
# 4           9988       18.176193           5699       17.747812
# 5           8244       15.002457           4797       14.938806
# 6           9933       18.076104           5952       18.535704
# 7           4856        8.836964           2999        9.339479
# 8           5553       10.105367           3445       10.728411
#
#    WEEK 3 INCOME  WEEK 3 PERCENT  WEEK 4 INCOME  WEEK 4 PERCENT  \
# 1           8641        9.147400           6474        8.952995
# 2           7523        7.963880           5657        7.823153
# 3           9893       10.472773           7347       10.160280
# 4          16663       17.639524          12900       17.839609
# 5          14348       15.188855          11126       15.386317
# 6          18282       19.353404          14085       19.478364
# 7           8756        9.269140           6855        9.479885
# 8          10358       10.965024           7867       10.879396
#
#    WEEK 5 INCOME  WEEK 5 PERCENT  ...  WEEK 8 INCOME  WEEK 8 PERCENT  \
# 1           7031        9.443922  ...           7602        9.755284
# 2           5984        8.037609  ...           6555        8.411719
# 3           7814       10.495635  ...           8439       10.829366
# 4          13326       17.899261  ...          13999       17.964249
# 5          11409       15.324379  ...          11782       15.119278
# 6          14494       19.468099  ...          14528       18.643089
# 7           6785        9.113499  ...           7029        9.019980
# 8           7607       10.217596  ...           7993       10.257035
#
#    WEEK 9 INCOME  WEEK 9 PERCENT  WEEK 10 INCOME  WEEK 10 PERCENT  \
# 1           7167       10.044145            6437         9.739454
# 2           6259        8.771635            5764         8.721177
# 3           7891       11.058791            7105        10.750166
# 4          12934       18.126270           11896        17.999153
# 5          10817       15.159414            9951        15.056285
# 6          13162       18.445799           12435        18.814683
# 7           6167        8.642702            5780         8.745385
# 8           6958        9.751244            6724        10.173697
#
#    WEEK 11 INCOME  WEEK 11 PERCENT  WEEK 12 INCOME  WEEK 12 PERCENT
# 1            6532         9.841055            6234         9.982706
# 2            5843         8.803013            5540         8.871381
# 3            7290        10.983051            6926        11.090828
# 4           11976        18.042938           11243        18.003779
# 5           10116        15.240678            9497        15.207853
# 6           12358        18.618456           11542        18.482578
# 7            5641         8.498682            5329         8.533500
# 8            6619         9.972128            6137         9.827376
#
# [8 rows x 24 columns]

# %%
plt.figure(1, figsize=(10, 8), dpi=80)

for i in range(8):
    week = white_income.iloc[i].to_frame()
    week = week[week.index.str.contains('PERCENT')]
    plt.plot(week, label='INCOME BRACKET ' + str(i + 1))
    
plt.xticks(positions, labels)
plt.legend()
plt.xlabel('Number of weeks')
plt.ylabel('Percent population in income bracket')
plt.title('Changes in percent White population distribution in 8 income brackets')
# Out:
# Text(0.5, 1.0, 'Changes in percent White population distribution in 8 income brackets')

# %% [markdown]
# ### Black

# %%
black_income = pd.DataFrame()

for i in range(len(phase1)):
    week = phase1[i][phase1[i]['RRACE'] == 2]
    
    week_income = week['INCOME'].value_counts().to_frame()
    num_drop = len([i for i in week_income.index if i < 0])
    week_income = week_income.sort_index().iloc[num_drop:]
    week_income['PERCENT'] = week_income['INCOME'] / week_income['INCOME'].sum() * 100
    
    black_income['WEEK ' + str(i + 1) + ' INCOME'] = week_income['INCOME']
    black_income['WEEK ' + str(i + 1) + ' PERCENT'] = week_income['PERCENT']
    
print(black_income)
# Out:
#    WEEK 1 INCOME  WEEK 1 PERCENT  WEEK 2 INCOME  WEEK 2 PERCENT  \
# 1           1345       25.215598            671       25.282592
# 2            854       16.010499            415       15.636775
# 3            817       15.316835            392       14.770158
# 4            919       17.229096            457       17.219292
# 5            529        9.917510            267       10.060286
# 6            523        9.805024            263        9.909570
# 7            207        3.880765            108        4.069329
# 8            140        2.624672             81        3.051997
#
#    WEEK 3 INCOME  WEEK 3 PERCENT  WEEK 4 INCOME  WEEK 4 PERCENT  \
# 1           1857       21.780436           1242       20.887992
# 2           1176       13.793103            810       13.622603
# 3           1255       14.719681            873       14.682139
# 4           1515       17.769177           1089       18.314834
# 5            990       11.611541            712       11.974437
# 6            977       11.459066            689       11.587622
# 7            422        4.949566            291        4.894046
# 8            334        3.917429            240        4.036327
#
#    WEEK 5 INCOME  WEEK 5 PERCENT  ...  WEEK 8 INCOME  WEEK 8 PERCENT  \
# 1           1509       22.448676  ...           1708       23.106061
# 2            966       14.370723  ...           1089       14.732143
# 3            953       14.177328  ...           1027       13.893398
# 4           1255       18.670039  ...           1354       18.317100
# 5            778       11.573936  ...            799       10.808983
# 6            738       10.978875  ...            816       11.038961
# 7            312        4.641476  ...            347        4.694264
# 8            211        3.138947  ...            252        3.409091
#
#    WEEK 9 INCOME  WEEK 9 PERCENT  WEEK 10 INCOME  WEEK 10 PERCENT  \
# 1           1652       23.834944            1353        22.610294
# 2           1024       14.774203             888        14.839572
# 3           1057       15.250325             909        15.190508
# 4           1252       18.063771            1088        18.181818
# 5            734       10.590102             640        10.695187
# 6            697       10.056269             631        10.544786
# 7            301        4.342808             277         4.629011
# 8            214        3.087578             198         3.308824
#
#    WEEK 11 INCOME  WEEK 11 PERCENT  WEEK 12 INCOME  WEEK 12 PERCENT
# 1            1356        22.309970            1258        21.954625
# 2             924        15.202369             894        15.602094
# 3             950        15.630141             924        16.125654
# 4            1082        17.801909             980        17.102967
# 5             661        10.875288             612        10.680628
# 6             632        10.398157             581        10.139616
# 7             247         4.063837             278         4.851658
# 8             226         3.718328             203         3.542757
#
# [8 rows x 24 columns]

# %%
plt.figure(3, figsize=(10, 8), dpi=80)

for i in range(8):
    week = black_income.iloc[i].to_frame()
    week = week[week.index.str.contains('PERCENT')]
    plt.plot(week, label='INCOME BRACKET ' + str(i + 1))
    
plt.xticks(positions, labels)
plt.legend()
plt.xlabel('Number of weeks')
plt.ylabel('Percent population in income bracket')
plt.title('Changes in percent Black population distribution in 8 income brackets')
# Out:
# Text(0.5, 1.0, 'Changes in percent Black population distribution in 8 income brackets')

# %% [markdown]
# ### Asian

# %%
asian_income = pd.DataFrame()

for i in range(len(phase1)):
    week = phase1[i][phase1[i]['RRACE'] == 3]
    
    week_income = week['INCOME'].value_counts().to_frame()
    num_drop = len([i for i in week_income.index if i < 0])
    week_income = week_income.sort_index().iloc[num_drop:]
    week_income['PERCENT'] = week_income['INCOME'] / week_income['INCOME'].sum() * 100
    
    asian_income['WEEK ' + str(i + 1) + ' INCOME'] = week_income['INCOME']
    asian_income['WEEK ' + str(i + 1) + ' PERCENT'] = week_income['PERCENT']
    
print(asian_income)
# Out:
#    WEEK 1 INCOME  WEEK 1 PERCENT  WEEK 2 INCOME  WEEK 2 PERCENT  \
# 1            214        7.359010            138        7.649667
# 2            174        5.983494            113        6.263858
# 3            255        8.768913            137        7.594235
# 4            421       14.477304            256       14.190687
# 5            383       13.170564            253       14.024390
# 6            618       21.251719            364       20.177384
# 7            350       12.035763            227       12.583149
# 8            493       16.953232            316       17.516630
#
#    WEEK 3 INCOME  WEEK 3 PERCENT  WEEK 4 INCOME  WEEK 4 PERCENT  \
# 1            439        7.826707            333        8.181818
# 2            358        6.382599            239        5.872236
# 3            435        7.755393            377        9.262899
# 4            785       13.995365            562       13.808354
# 5            756       13.478338            553       13.587224
# 6           1103       19.664824            823       20.221130
# 7            696       12.408629            496       12.186732
# 8           1037       18.488144            687       16.879607
#
#    WEEK 5 INCOME  WEEK 5 PERCENT  ...  WEEK 8 INCOME  WEEK 8 PERCENT  \
# 1            340        8.351756  ...            375        8.573388
# 2            278        6.828789  ...            336        7.681756
# 3            369        9.064112  ...            421        9.625057
# 4            581       14.271678  ...            678       15.500686
# 5            532       13.068042  ...            570       13.031550
# 6            816       20.044215  ...            817       18.678555
# 7            484       11.888971  ...            464       10.608139
# 8            671       16.482437  ...            713       16.300869
#
#    WEEK 9 INCOME  WEEK 9 PERCENT  WEEK 10 INCOME  WEEK 10 PERCENT  \
# 1            328        8.725725             340         9.767308
# 2            250        6.650705             232         6.664752
# 3            359        9.550412             318         9.135306
# 4            555       14.764565             511        14.679690
# 5            561       14.924182             470        13.501867
# 6            718       19.100825             659        18.931342
# 7            407       10.827348             361        10.370583
# 8            581       15.456238             590        16.949153
#
#    WEEK 11 INCOME  WEEK 11 PERCENT  WEEK 12 INCOME  WEEK 12 PERCENT
# 1             310         9.152642             283         8.667688
# 2             237         6.997343             265         8.116386
# 3             339        10.008857             331        10.137825
# 4             504        14.880425             538        16.477795
# 5             456        13.463242             443        13.568147
# 6             628        18.541482             593        18.162328
# 7             348        10.274579             346        10.597243
# 8             565        16.681429             466        14.272588
#
# [8 rows x 24 columns]

# %%
plt.figure(1, figsize=(10, 8), dpi=80)

for i in range(8):
    week = asian_income.iloc[i].to_frame()
    week = week[week.index.str.contains('PERCENT')]
    plt.plot(week, label='INCOME BRACKET ' + str(i + 1))
    
plt.xticks(positions, labels)
plt.legend()
plt.xlabel('Number of weeks')
plt.ylabel('Percent population in income bracket')
plt.title('Changes in percent Asian population distribution in 8 income brackets')
# Out:
# Text(0.5, 1.0, 'Changes in percent Asian population distribution in 8 income brackets')
